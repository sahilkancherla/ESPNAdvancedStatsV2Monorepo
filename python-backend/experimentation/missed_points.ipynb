# %%
from dotenv import load_dotenv
import os
from espn_api.football import League
import json

# %%
load_dotenv()

league_id = os.getenv('LEAGUE_ID')
swid = os.getenv('SWID')
espn_s2 = os.getenv('ESPN_S2')
year = 2024
week = 1

# %%
league = League(league_id=league_id, year=year, espn_s2=espn_s2, swid=swid)

# %%
player_name = "Justin Herbert"
def get_all_player_fantasy_weekly_stats(league, player_name, year):
    fantasy_player_weekly_stats = []
    player_found_in_rosters = False
    
    for week in range(1, 19):
        box_scores = league.box_scores(week=week)
        week_found = False
        
        # Check rosters first
        for box_score in box_scores:
            lineup_1 = box_score.home_lineup
            lineup_2 = box_score.away_lineup
            
            for player in lineup_1 + lineup_2:
                if player.name == player_name:
                    fantasy_player_weekly_stats.append({
                        "player_name": player.name,
                        "week": week,
                        "year": year,
                        "total_points": player.points,
                        "projected_points": player.projected_points,
                        "slot": player.slot_position
                    })
                    player_found_in_rosters = True
                    week_found = True
                    break
            
            if week_found:
                break
        
        # If player not found in rosters for this week, check player pool
        if not week_found:
            try:
                # Get all players from player pool for this week
                # This is more comprehensive than free_agents()
                players = league.player_info(name=player_name, size=50)
                
                for player in players:
                    if player.name == player_name:
                        # Get week-specific stats
                        week_stats = player.stats.get(week, {})
                        fantasy_player_weekly_stats.append({
                            "player_name": player.name,
                            "week": week,
                            "year": year,
                            "total_points": week_stats.get('points', 0),
                            "projected_points": week_stats.get('projected_points', 0),
                            "slot": "FA"  # Free agent
                        })
                        week_found = True
                        break
                        
            except Exception as e:
                # If player_info doesn't work, try alternative approach
                print(f"Could not find {player_name} in player pool for week {week}: {e}")
    
    # If player was never found in any roster, try to get their stats directly
    if not player_found_in_rosters:
        try:
            # Alternative: Access ESPN API directly for player stats
            # This requires making direct API calls to ESPN
            print(f"Player {player_name} was never rostered. Attempting direct API access...")
            # You might need to implement direct ESPN API calls here
            
        except Exception as e:
            print(f"Could not access player stats directly: {e}")
    
    return fantasy_player_weekly_stats
    
fantasy_player_weekly_stats = get_all_player_fantasy_weekly_stats(league, player_name, year)
print(json.dumps(fantasy_player_weekly_stats, indent=2))
# Out:
# Could not find Justin Herbert in player pool for week 1: League.player_info() got an unexpected keyword argument 'size'
# Could not find Justin Herbert in player pool for week 2: League.player_info() got an unexpected keyword argument 'size'
# Could not find Justin Herbert in player pool for week 3: League.player_info() got an unexpected keyword argument 'size'
# Could not find Justin Herbert in player pool for week 4: League.player_info() got an unexpected keyword argument 'size'
# Could not find Justin Herbert in player pool for week 5: League.player_info() got an unexpected keyword argument 'size'
# Could not find Justin Herbert in player pool for week 6: League.player_info() got an unexpected keyword argument 'size'
# Could not find Justin Herbert in player pool for week 7: League.player_info() got an unexpected keyword argument 'size'
# Could not find Justin Herbert in player pool for week 8: League.player_info() got an unexpected keyword argument 'size'
# [
#   {
#     "player_name": "Justin Herbert",
#     "week": 9,
#     "year": 2024,
#     "total_points": 22.48,
#     "projected_points": 16.56,
#     "slot": "BE"
#   },
#   {
#     "player_name": "Justin Herbert",
#     "week": 10,
#     "year": 2024,
#     "total_points": 19.76,
#     "projected_points": 15.88,
#     "slot": "BE"
#   },
#   {
#     "player_name": "Justin Herbert",
#     "week": 11,
#     "year": 2024,
#     "total_points": 24.38,
#     "projected_points": 17.93,
#     "slot": "QB"
#   },
#   {
#     "player_name": "Justin Herbert",
#     "week": 12,
#     "year": 2024,
#     "total_points": 17.62,
#     "projected_points": 18.57,
#     "slot": "QB"
#   },
#   {
#     "player_name": "Justin Herbert",
#     "week": 13,
#     "year": 2024,
#     "total_points": 7.98,
#     "projected_points": 19.12,
#     "slot": "BE"
#   },
#   {
#     "player_name": "Justin Herbert",
#     "week": 14,
#     "year": 2024,
#     "total_points": 13.72,
#     "projected_points": 18.05,
#     "slot": "QB"
#   },
#   {
#     "player_name": "Justin Herbert",
#     "week": 15,
#     "year": 2024,
#     "total_points": 13.8,
#     "projected_points": 18.49,
#     "slot": "QB"
#   },
#   {
#     "player_name": "Justin Herbert",
#     "week": 16,
#     "year": 2024,
#     "total_points": 22.16,
#     "projected_points": 15.28,
#     "slot": "BE"
#   },
#   {
#     "player_name": "Justin Herbert",
#     "week": 17,
#     "year": 2024,
#     "total_points": 25.44,
#     "projected_points": 18.34,
#     "slot": "BE"
#   },
#   {
#     "player_name": "Justin Herbert",
#     "week": 18,
#     "year": 2024,
#     "total_points": 25.44,
#     "projected_points": 18.34,
#     "slot": "BE"
#   }
# ]

# %%
def get_fantasy_player_weekly_stats(league, week, year):
    fantasy_player_weekly_stats = {}
    box_scores = league.box_scores(week=week)
    for box_score in box_scores:
        lineup_1 = box_score.home_lineup
        lineup_2 = box_score.away_lineup
        
        for player in lineup_1:
            
            fantasy_player_weekly_stats[player.name] = {
                "player_name": player.name,
                "week": week,
                "year": year,
                "total_points": player.points,
                "projected_points": player.projected_points,
                "slot": player.slot_position
                
            }
        
        for player in lineup_2:
            
            fantasy_player_weekly_stats[player.name] = {
                "player_name": player.name,
                "week": week,
                "year": year,
                "total_points": player.points,
                "projected_points": player.projected_points,
                "slot": player.slot_position
            }
    
    
    free_agents = league.free_agents(week=week, size=5000)
    
    for player in free_agents:

                
        fantasy_player_weekly_stats[player.name] = {
            "player_name": player.name,
            "week": week,
            "year": year,
            "total_points": player.points,
            "projected_points": player.projected_points,
            "slot": player.slot_position
        }
    
    return fantasy_player_weekly_stats
    
fantasy_player_weekly_stats = get_fantasy_player_weekly_stats(league, week, year)
print(json.dumps(fantasy_player_weekly_stats, indent=2))
# Out:
# {
#   "Mohamed Ibrahim": {
#     "player_name": "Mohamed Ibrahim",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "RB/WR/TE"
#   },
#   "Ramiz Ahmed": {
#     "player_name": "Ramiz Ahmed",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "K"
#   },
#   "Jonathan Taylor": {
#     "player_name": "Jonathan Taylor",
#     "week": 1,
#     "year": 2024,
#     "total_points": 10.8,
#     "projected_points": 15.6,
#     "slot": "RB"
#   },
#   "A.J. Brown": {
#     "player_name": "A.J. Brown",
#     "week": 1,
#     "year": 2024,
#     "total_points": 23.4,
#     "projected_points": 14.27,
#     "slot": "WR"
#   },
#   "James Cook": {
#     "player_name": "James Cook",
#     "week": 1,
#     "year": 2024,
#     "total_points": 11.8,
#     "projected_points": 15.73,
#     "slot": "RB"
#   },
#   "Michael Pittman Jr.": {
#     "player_name": "Michael Pittman Jr.",
#     "week": 1,
#     "year": 2024,
#     "total_points": 5.1,
#     "projected_points": 12.23,
#     "slot": "FA"
#   },
#   "Malik Nabers": {
#     "player_name": "Malik Nabers",
#     "week": 1,
#     "year": 2024,
#     "total_points": 9.1,
#     "projected_points": 11.46,
#     "slot": "RB/WR/TE"
#   },
#   "Trey McBride": {
#     "player_name": "Trey McBride",
#     "week": 1,
#     "year": 2024,
#     "total_points": 5.5,
#     "projected_points": 9.66,
#     "slot": "TE"
#   },
#   "Javonte Williams": {
#     "player_name": "Javonte Williams",
#     "week": 1,
#     "year": 2024,
#     "total_points": 2.8,
#     "projected_points": 10.7,
#     "slot": "BE"
#   },
#   "Jaxon Smith-Njigba": {
#     "player_name": "Jaxon Smith-Njigba",
#     "week": 1,
#     "year": 2024,
#     "total_points": 2.9,
#     "projected_points": 10.23,
#     "slot": "BE"
#   },
#   "Devin Singletary": {
#     "player_name": "Devin Singletary",
#     "week": 1,
#     "year": 2024,
#     "total_points": 7.2,
#     "projected_points": 10.9,
#     "slot": "FA"
#   },
#   "Jaylen Warren": {
#     "player_name": "Jaylen Warren",
#     "week": 1,
#     "year": 2024,
#     "total_points": 3.0,
#     "projected_points": 8.48,
#     "slot": "BE"
#   },
#   "Lamar Jackson": {
#     "player_name": "Lamar Jackson",
#     "week": 1,
#     "year": 2024,
#     "total_points": 26.12,
#     "projected_points": 20.72,
#     "slot": "QB"
#   },
#   "Dolphins D/ST": {
#     "player_name": "Dolphins D/ST",
#     "week": 1,
#     "year": 2024,
#     "total_points": 8.0,
#     "projected_points": 6.88,
#     "slot": "D/ST"
#   },
#   "Jayden Daniels": {
#     "player_name": "Jayden Daniels",
#     "week": 1,
#     "year": 2024,
#     "total_points": 28.16,
#     "projected_points": 18.3,
#     "slot": "BE"
#   },
#   "Ravens D/ST": {
#     "player_name": "Ravens D/ST",
#     "week": 1,
#     "year": 2024,
#     "total_points": 3.0,
#     "projected_points": 3.77,
#     "slot": "BE"
#   },
#   "Jameson Williams": {
#     "player_name": "Jameson Williams",
#     "week": 1,
#     "year": 2024,
#     "total_points": 24.9,
#     "projected_points": 8.91,
#     "slot": "FA"
#   },
#   "Keaton Mitchell": {
#     "player_name": "Keaton Mitchell",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0.0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Cameron Dicker": {
#     "player_name": "Cameron Dicker",
#     "week": 1,
#     "year": 2024,
#     "total_points": 12.0,
#     "projected_points": 8.24,
#     "slot": "K"
#   },
#   "Christian McCaffrey": {
#     "player_name": "Christian McCaffrey",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0.0,
#     "projected_points": 0.0,
#     "slot": "BE"
#   },
#   "CeeDee Lamb": {
#     "player_name": "CeeDee Lamb",
#     "week": 1,
#     "year": 2024,
#     "total_points": 11.1,
#     "projected_points": 16.51,
#     "slot": "WR"
#   },
#   "De'Von Achane": {
#     "player_name": "De'Von Achane",
#     "week": 1,
#     "year": 2024,
#     "total_points": 19.5,
#     "projected_points": 12.49,
#     "slot": "RB/WR/TE"
#   },
#   "Josh Allen": {
#     "player_name": "Josh Allen",
#     "week": 1,
#     "year": 2024,
#     "total_points": 31.18,
#     "projected_points": 24.16,
#     "slot": "QB"
#   },
#   "Tank Dell": {
#     "player_name": "Tank Dell",
#     "week": 1,
#     "year": 2024,
#     "total_points": 7.4,
#     "projected_points": 11.88,
#     "slot": "BE"
#   },
#   "David Montgomery": {
#     "player_name": "David Montgomery",
#     "week": 1,
#     "year": 2024,
#     "total_points": 15.8,
#     "projected_points": 12.13,
#     "slot": "RB"
#   },
#   "Calvin Ridley": {
#     "player_name": "Calvin Ridley",
#     "week": 1,
#     "year": 2024,
#     "total_points": 6.5,
#     "projected_points": 11.99,
#     "slot": "FA"
#   },
#   "Diontae Johnson": {
#     "player_name": "Diontae Johnson",
#     "week": 1,
#     "year": 2024,
#     "total_points": 2.9,
#     "projected_points": 11.03,
#     "slot": "FA"
#   },
#   "Christian Kirk": {
#     "player_name": "Christian Kirk",
#     "week": 1,
#     "year": 2024,
#     "total_points": 3.5,
#     "projected_points": 10.15,
#     "slot": "FA"
#   },
#   "Chris Godwin": {
#     "player_name": "Chris Godwin",
#     "week": 1,
#     "year": 2024,
#     "total_points": 18.3,
#     "projected_points": 11.4,
#     "slot": "FA"
#   },
#   "Zack Moss": {
#     "player_name": "Zack Moss",
#     "week": 1,
#     "year": 2024,
#     "total_points": 13.1,
#     "projected_points": 9.89,
#     "slot": "FA"
#   },
#   "Jordan Mason": {
#     "player_name": "Jordan Mason",
#     "week": 1,
#     "year": 2024,
#     "total_points": 21.7,
#     "projected_points": 3.04,
#     "slot": "FA"
#   },
#   "Cowboys D/ST": {
#     "player_name": "Cowboys D/ST",
#     "week": 1,
#     "year": 2024,
#     "total_points": 19.0,
#     "projected_points": 6.94,
#     "slot": "D/ST"
#   },
#   "Jake Elliott": {
#     "player_name": "Jake Elliott",
#     "week": 1,
#     "year": 2024,
#     "total_points": 10.0,
#     "projected_points": 8.43,
#     "slot": "FA"
#   },
#   "Taysom Hill": {
#     "player_name": "Taysom Hill",
#     "week": 1,
#     "year": 2024,
#     "total_points": 4.1,
#     "projected_points": 6.51,
#     "slot": "FA"
#   },
#   "T.J. Hockenson": {
#     "player_name": "T.J. Hockenson",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0.0,
#     "projected_points": 0.0,
#     "slot": "IR"
#   },
#   "Jaleel McLaughlin": {
#     "player_name": "Jaleel McLaughlin",
#     "week": 1,
#     "year": 2024,
#     "total_points": 3.3,
#     "projected_points": 6.81,
#     "slot": "FA"
#   },
#   "Jahmyr Gibbs": {
#     "player_name": "Jahmyr Gibbs",
#     "week": 1,
#     "year": 2024,
#     "total_points": 15.4,
#     "projected_points": 14.91,
#     "slot": "RB"
#   },
#   "Chris Olave": {
#     "player_name": "Chris Olave",
#     "week": 1,
#     "year": 2024,
#     "total_points": 2.1,
#     "projected_points": 13.51,
#     "slot": "WR"
#   },
#   "Drake London": {
#     "player_name": "Drake London",
#     "week": 1,
#     "year": 2024,
#     "total_points": 2.5,
#     "projected_points": 11.66,
#     "slot": "BE"
#   },
#   "Kenneth Walker III": {
#     "player_name": "Kenneth Walker III",
#     "week": 1,
#     "year": 2024,
#     "total_points": 17.9,
#     "projected_points": 15.22,
#     "slot": "RB"
#   },
#   "Cooper Kupp": {
#     "player_name": "Cooper Kupp",
#     "week": 1,
#     "year": 2024,
#     "total_points": 25.0,
#     "projected_points": 12.11,
#     "slot": "RB/WR/TE"
#   },
#   "Kyler Murray": {
#     "player_name": "Kyler Murray",
#     "week": 1,
#     "year": 2024,
#     "total_points": 14.18,
#     "projected_points": 18.39,
#     "slot": "QB"
#   },
#   "Jonathon Brooks": {
#     "player_name": "Jonathon Brooks",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0.0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Courtland Sutton": {
#     "player_name": "Courtland Sutton",
#     "week": 1,
#     "year": 2024,
#     "total_points": 5.8,
#     "projected_points": 9.65,
#     "slot": "BE"
#   },
#   "Blake Corum": {
#     "player_name": "Blake Corum",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0.0,
#     "projected_points": 5.32,
#     "slot": "FA"
#   },
#   "Caleb Williams": {
#     "player_name": "Caleb Williams",
#     "week": 1,
#     "year": 2024,
#     "total_points": 7.22,
#     "projected_points": 17.74,
#     "slot": "BE"
#   },
#   "Tyjae Spears": {
#     "player_name": "Tyjae Spears",
#     "week": 1,
#     "year": 2024,
#     "total_points": 5.2,
#     "projected_points": 9.17,
#     "slot": "BE"
#   },
#   "Younghoe Koo": {
#     "player_name": "Younghoe Koo",
#     "week": 1,
#     "year": 2024,
#     "total_points": 4.0,
#     "projected_points": 7.8,
#     "slot": "FA"
#   },
#   "Saints D/ST": {
#     "player_name": "Saints D/ST",
#     "week": 1,
#     "year": 2024,
#     "total_points": 16.0,
#     "projected_points": 7.24,
#     "slot": "D/ST"
#   },
#   "DeMario Douglas": {
#     "player_name": "DeMario Douglas",
#     "week": 1,
#     "year": 2024,
#     "total_points": 2.2,
#     "projected_points": 9.04,
#     "slot": "FA"
#   },
#   "Bucky Irving": {
#     "player_name": "Bucky Irving",
#     "week": 1,
#     "year": 2024,
#     "total_points": 8.6,
#     "projected_points": 5.34,
#     "slot": "BE"
#   },
#   "Davante Adams": {
#     "player_name": "Davante Adams",
#     "week": 1,
#     "year": 2024,
#     "total_points": 8.4,
#     "projected_points": 13.39,
#     "slot": "WR"
#   },
#   "George Kittle": {
#     "player_name": "George Kittle",
#     "week": 1,
#     "year": 2024,
#     "total_points": 6.0,
#     "projected_points": 9.3,
#     "slot": "TE"
#   },
#   "Breece Hall": {
#     "player_name": "Breece Hall",
#     "week": 1,
#     "year": 2024,
#     "total_points": 15.8,
#     "projected_points": 15.62,
#     "slot": "RB"
#   },
#   "Derrick Henry": {
#     "player_name": "Derrick Henry",
#     "week": 1,
#     "year": 2024,
#     "total_points": 10.6,
#     "projected_points": 13.87,
#     "slot": "RB"
#   },
#   "Nico Collins": {
#     "player_name": "Nico Collins",
#     "week": 1,
#     "year": 2024,
#     "total_points": 14.7,
#     "projected_points": 12.1,
#     "slot": "WR"
#   },
#   "Brandon Aiyuk": {
#     "player_name": "Brandon Aiyuk",
#     "week": 1,
#     "year": 2024,
#     "total_points": 3.8,
#     "projected_points": 11.23,
#     "slot": "FA"
#   },
#   "Christian Watson": {
#     "player_name": "Christian Watson",
#     "week": 1,
#     "year": 2024,
#     "total_points": 8.8,
#     "projected_points": 10.61,
#     "slot": "FA"
#   },
#   "Austin Ekeler": {
#     "player_name": "Austin Ekeler",
#     "week": 1,
#     "year": 2024,
#     "total_points": 8.2,
#     "projected_points": 10.37,
#     "slot": "FA"
#   },
#   "Xavier Worthy": {
#     "player_name": "Xavier Worthy",
#     "week": 1,
#     "year": 2024,
#     "total_points": 19.8,
#     "projected_points": 10.36,
#     "slot": "BE"
#   },
#   "David Njoku": {
#     "player_name": "David Njoku",
#     "week": 1,
#     "year": 2024,
#     "total_points": 6.4,
#     "projected_points": 8.9,
#     "slot": "FA"
#   },
#   "Mike Williams": {
#     "player_name": "Mike Williams",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0.0,
#     "projected_points": 6.34,
#     "slot": "FA"
#   },
#   "Zach Charbonnet": {
#     "player_name": "Zach Charbonnet",
#     "week": 1,
#     "year": 2024,
#     "total_points": 11.1,
#     "projected_points": 7.77,
#     "slot": "BE"
#   },
#   "Browns D/ST": {
#     "player_name": "Browns D/ST",
#     "week": 1,
#     "year": 2024,
#     "total_points": 4.0,
#     "projected_points": 6.5,
#     "slot": "FA"
#   },
#   "Greg Zuerlein": {
#     "player_name": "Greg Zuerlein",
#     "week": 1,
#     "year": 2024,
#     "total_points": 1.0,
#     "projected_points": 7.86,
#     "slot": "FA"
#   },
#   "Jaylen Waddle": {
#     "player_name": "Jaylen Waddle",
#     "week": 1,
#     "year": 2024,
#     "total_points": 13.7,
#     "projected_points": 11.25,
#     "slot": "FA"
#   },
#   "C.J. Stroud": {
#     "player_name": "C.J. Stroud",
#     "week": 1,
#     "year": 2024,
#     "total_points": 18.66,
#     "projected_points": 19.77,
#     "slot": "FA"
#   },
#   "Evan Engram": {
#     "player_name": "Evan Engram",
#     "week": 1,
#     "year": 2024,
#     "total_points": 1.0,
#     "projected_points": 9.07,
#     "slot": "FA"
#   },
#   "D'Andre Swift": {
#     "player_name": "D'Andre Swift",
#     "week": 1,
#     "year": 2024,
#     "total_points": 5.0,
#     "projected_points": 11.4,
#     "slot": "RB/WR/TE"
#   },
#   "Bijan Robinson": {
#     "player_name": "Bijan Robinson",
#     "week": 1,
#     "year": 2024,
#     "total_points": 13.6,
#     "projected_points": 16.43,
#     "slot": "RB"
#   },
#   "Isiah Pacheco": {
#     "player_name": "Isiah Pacheco",
#     "week": 1,
#     "year": 2024,
#     "total_points": 14.8,
#     "projected_points": 13.71,
#     "slot": "RB"
#   },
#   "Alvin Kamara": {
#     "player_name": "Alvin Kamara",
#     "week": 1,
#     "year": 2024,
#     "total_points": 19.5,
#     "projected_points": 15.18,
#     "slot": "RB/WR/TE"
#   },
#   "Zay Flowers": {
#     "player_name": "Zay Flowers",
#     "week": 1,
#     "year": 2024,
#     "total_points": 8.1,
#     "projected_points": 12.14,
#     "slot": "BE"
#   },
#   "Rashee Rice": {
#     "player_name": "Rashee Rice",
#     "week": 1,
#     "year": 2024,
#     "total_points": 13.8,
#     "projected_points": 11.5,
#     "slot": "FA"
#   },
#   "Keenan Allen": {
#     "player_name": "Keenan Allen",
#     "week": 1,
#     "year": 2024,
#     "total_points": 4.9,
#     "projected_points": 10.26,
#     "slot": "BE"
#   },
#   "Chase Brown": {
#     "player_name": "Chase Brown",
#     "week": 1,
#     "year": 2024,
#     "total_points": 3.8,
#     "projected_points": 10.14,
#     "slot": "BE"
#   },
#   "Justin Tucker": {
#     "player_name": "Justin Tucker",
#     "week": 1,
#     "year": 2024,
#     "total_points": 7.0,
#     "projected_points": 8.23,
#     "slot": "FA"
#   },
#   "Brock Bowers": {
#     "player_name": "Brock Bowers",
#     "week": 1,
#     "year": 2024,
#     "total_points": 8.8,
#     "projected_points": 7.91,
#     "slot": "BE"
#   },
#   "49ers D/ST": {
#     "player_name": "49ers D/ST",
#     "week": 1,
#     "year": 2024,
#     "total_points": 7.0,
#     "projected_points": 5.75,
#     "slot": "FA"
#   },
#   "Steelers D/ST": {
#     "player_name": "Steelers D/ST",
#     "week": 1,
#     "year": 2024,
#     "total_points": 13.0,
#     "projected_points": 6.16,
#     "slot": "D/ST"
#   },
#   "Garrett Wilson": {
#     "player_name": "Garrett Wilson",
#     "week": 1,
#     "year": 2024,
#     "total_points": 9.0,
#     "projected_points": 13.76,
#     "slot": "WR"
#   },
#   "Jordan Love": {
#     "player_name": "Jordan Love",
#     "week": 1,
#     "year": 2024,
#     "total_points": 19.4,
#     "projected_points": 18.94,
#     "slot": "QB"
#   },
#   "Dalton Kincaid": {
#     "player_name": "Dalton Kincaid",
#     "week": 1,
#     "year": 2024,
#     "total_points": 1.6,
#     "projected_points": 9.2,
#     "slot": "TE"
#   },
#   "DeVonta Smith": {
#     "player_name": "DeVonta Smith",
#     "week": 1,
#     "year": 2024,
#     "total_points": 11.9,
#     "projected_points": 11.85,
#     "slot": "BE"
#   },
#   "Rico Dowdle": {
#     "player_name": "Rico Dowdle",
#     "week": 1,
#     "year": 2024,
#     "total_points": 3.7,
#     "projected_points": 6.06,
#     "slot": "FA"
#   },
#   "Amon-Ra St. Brown": {
#     "player_name": "Amon-Ra St. Brown",
#     "week": 1,
#     "year": 2024,
#     "total_points": 2.8,
#     "projected_points": 15.83,
#     "slot": "WR"
#   },
#   "Marvin Harrison Jr.": {
#     "player_name": "Marvin Harrison Jr.",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0.9,
#     "projected_points": 12.66,
#     "slot": "WR"
#   },
#   "Mike Evans": {
#     "player_name": "Mike Evans",
#     "week": 1,
#     "year": 2024,
#     "total_points": 20.6,
#     "projected_points": 12.84,
#     "slot": "RB/WR/TE"
#   },
#   "Patrick Mahomes": {
#     "player_name": "Patrick Mahomes",
#     "week": 1,
#     "year": 2024,
#     "total_points": 14.64,
#     "projected_points": 20.03,
#     "slot": "QB"
#   },
#   "Joe Mixon": {
#     "player_name": "Joe Mixon",
#     "week": 1,
#     "year": 2024,
#     "total_points": 25.3,
#     "projected_points": 14.82,
#     "slot": "RB"
#   },
#   "Raheem Mostert": {
#     "player_name": "Raheem Mostert",
#     "week": 1,
#     "year": 2024,
#     "total_points": 2.9,
#     "projected_points": 10.42,
#     "slot": "FA"
#   },
#   "Zamir White": {
#     "player_name": "Zamir White",
#     "week": 1,
#     "year": 2024,
#     "total_points": 3.6,
#     "projected_points": 12.12,
#     "slot": "FA"
#   },
#   "Tony Pollard": {
#     "player_name": "Tony Pollard",
#     "week": 1,
#     "year": 2024,
#     "total_points": 16.9,
#     "projected_points": 9.82,
#     "slot": "FA"
#   },
#   "Brian Thomas Jr.": {
#     "player_name": "Brian Thomas Jr.",
#     "week": 1,
#     "year": 2024,
#     "total_points": 12.7,
#     "projected_points": 8.95,
#     "slot": "BE"
#   },
#   "Trey Benson": {
#     "player_name": "Trey Benson",
#     "week": 1,
#     "year": 2024,
#     "total_points": 2.3,
#     "projected_points": 5.39,
#     "slot": "FA"
#   },
#   "Tyler Bass": {
#     "player_name": "Tyler Bass",
#     "week": 1,
#     "year": 2024,
#     "total_points": 10.0,
#     "projected_points": 8.04,
#     "slot": "K"
#   },
#   "Tyler Allgeier": {
#     "player_name": "Tyler Allgeier",
#     "week": 1,
#     "year": 2024,
#     "total_points": 2.1,
#     "projected_points": 6.84,
#     "slot": "FA"
#   },
#   "Jakobi Meyers": {
#     "player_name": "Jakobi Meyers",
#     "week": 1,
#     "year": 2024,
#     "total_points": 7.9,
#     "projected_points": 8.91,
#     "slot": "BE"
#   },
#   "Rhamondre Stevenson": {
#     "player_name": "Rhamondre Stevenson",
#     "week": 1,
#     "year": 2024,
#     "total_points": 20.1,
#     "projected_points": 11.5,
#     "slot": "BE"
#   },
#   "Travis Kelce": {
#     "player_name": "Travis Kelce",
#     "week": 1,
#     "year": 2024,
#     "total_points": 4.9,
#     "projected_points": 11.32,
#     "slot": "TE"
#   },
#   "Falcons D/ST": {
#     "player_name": "Falcons D/ST",
#     "week": 1,
#     "year": 2024,
#     "total_points": 4.0,
#     "projected_points": 7.57,
#     "slot": "D/ST"
#   },
#   "Justin Jefferson": {
#     "player_name": "Justin Jefferson",
#     "week": 1,
#     "year": 2024,
#     "total_points": 13.9,
#     "projected_points": 14.86,
#     "slot": "FA"
#   },
#   "DK Metcalf": {
#     "player_name": "DK Metcalf",
#     "week": 1,
#     "year": 2024,
#     "total_points": 4.4,
#     "projected_points": 11.91,
#     "slot": "WR"
#   },
#   "Josh Jacobs": {
#     "player_name": "Josh Jacobs",
#     "week": 1,
#     "year": 2024,
#     "total_points": 11.4,
#     "projected_points": 14.38,
#     "slot": "RB"
#   },
#   "James Conner": {
#     "player_name": "James Conner",
#     "week": 1,
#     "year": 2024,
#     "total_points": 17.8,
#     "projected_points": 12.15,
#     "slot": "FA"
#   },
#   "Kyle Pitts": {
#     "player_name": "Kyle Pitts",
#     "week": 1,
#     "year": 2024,
#     "total_points": 10.1,
#     "projected_points": 8.51,
#     "slot": "TE"
#   },
#   "Brian Robinson Jr.": {
#     "player_name": "Brian Robinson Jr.",
#     "week": 1,
#     "year": 2024,
#     "total_points": 16.4,
#     "projected_points": 10.73,
#     "slot": "FA"
#   },
#   "Jayden Reed": {
#     "player_name": "Jayden Reed",
#     "week": 1,
#     "year": 2024,
#     "total_points": 34.1,
#     "projected_points": 10.73,
#     "slot": "BE"
#   },
#   "Ladd McConkey": {
#     "player_name": "Ladd McConkey",
#     "week": 1,
#     "year": 2024,
#     "total_points": 12.4,
#     "projected_points": 9.01,
#     "slot": "BE"
#   },
#   "Joe Burrow": {
#     "player_name": "Joe Burrow",
#     "week": 1,
#     "year": 2024,
#     "total_points": 8.06,
#     "projected_points": 19.78,
#     "slot": "FA"
#   },
#   "Jake Ferguson": {
#     "player_name": "Jake Ferguson",
#     "week": 1,
#     "year": 2024,
#     "total_points": 3.0,
#     "projected_points": 8.3,
#     "slot": "FA"
#   },
#   "Dak Prescott": {
#     "player_name": "Dak Prescott",
#     "week": 1,
#     "year": 2024,
#     "total_points": 11.46,
#     "projected_points": 17.19,
#     "slot": "FA"
#   },
#   "Chiefs D/ST": {
#     "player_name": "Chiefs D/ST",
#     "week": 1,
#     "year": 2024,
#     "total_points": -2.0,
#     "projected_points": 5.25,
#     "slot": "FA"
#   },
#   "Harrison Butker": {
#     "player_name": "Harrison Butker",
#     "week": 1,
#     "year": 2024,
#     "total_points": 9.0,
#     "projected_points": 8.4,
#     "slot": "FA"
#   },
#   "DJ Moore": {
#     "player_name": "DJ Moore",
#     "week": 1,
#     "year": 2024,
#     "total_points": 7.5,
#     "projected_points": 11.36,
#     "slot": "FA"
#   },
#   "Tee Higgins": {
#     "player_name": "Tee Higgins",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0.0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Kyren Williams": {
#     "player_name": "Kyren Williams",
#     "week": 1,
#     "year": 2024,
#     "total_points": 12.9,
#     "projected_points": 15.77,
#     "slot": "FA"
#   },
#   "Tyreek Hill": {
#     "player_name": "Tyreek Hill",
#     "week": 1,
#     "year": 2024,
#     "total_points": 26.6,
#     "projected_points": 16.28,
#     "slot": "WR"
#   },
#   "Travis Etienne Jr.": {
#     "player_name": "Travis Etienne Jr.",
#     "week": 1,
#     "year": 2024,
#     "total_points": 10.9,
#     "projected_points": 12.72,
#     "slot": "RB"
#   },
#   "Puka Nacua": {
#     "player_name": "Puka Nacua",
#     "week": 1,
#     "year": 2024,
#     "total_points": 6.2,
#     "projected_points": 14.19,
#     "slot": "WR"
#   },
#   "Sam LaPorta": {
#     "player_name": "Sam LaPorta",
#     "week": 1,
#     "year": 2024,
#     "total_points": 6.5,
#     "projected_points": 11.34,
#     "slot": "TE"
#   },
#   "Stefon Diggs": {
#     "player_name": "Stefon Diggs",
#     "week": 1,
#     "year": 2024,
#     "total_points": 18.9,
#     "projected_points": 11.63,
#     "slot": "FA"
#   },
#   "Najee Harris": {
#     "player_name": "Najee Harris",
#     "week": 1,
#     "year": 2024,
#     "total_points": 8.4,
#     "projected_points": 10.51,
#     "slot": "BE"
#   },
#   "Brandon Aubrey": {
#     "player_name": "Brandon Aubrey",
#     "week": 1,
#     "year": 2024,
#     "total_points": 21.0,
#     "projected_points": 7.87,
#     "slot": "K"
#   },
#   "Ezekiel Elliott": {
#     "player_name": "Ezekiel Elliott",
#     "week": 1,
#     "year": 2024,
#     "total_points": 11.9,
#     "projected_points": 8.79,
#     "slot": "FA"
#   },
#   "Keon Coleman": {
#     "player_name": "Keon Coleman",
#     "week": 1,
#     "year": 2024,
#     "total_points": 7.1,
#     "projected_points": 9.73,
#     "slot": "BE"
#   },
#   "Jordan Addison": {
#     "player_name": "Jordan Addison",
#     "week": 1,
#     "year": 2024,
#     "total_points": 5.0,
#     "projected_points": 9.59,
#     "slot": "BE"
#   },
#   "Jets D/ST": {
#     "player_name": "Jets D/ST",
#     "week": 1,
#     "year": 2024,
#     "total_points": -1.0,
#     "projected_points": 3.85,
#     "slot": "FA"
#   },
#   "Ty Chandler": {
#     "player_name": "Ty Chandler",
#     "week": 1,
#     "year": 2024,
#     "total_points": 5.7,
#     "projected_points": 8.37,
#     "slot": "FA"
#   },
#   "Rome Odunze": {
#     "player_name": "Rome Odunze",
#     "week": 1,
#     "year": 2024,
#     "total_points": 1.6,
#     "projected_points": 8.1,
#     "slot": "FA"
#   },
#   "Aaron Jones": {
#     "player_name": "Aaron Jones",
#     "week": 1,
#     "year": 2024,
#     "total_points": 17.9,
#     "projected_points": 12.29,
#     "slot": "RB"
#   },
#   "Jalen Hurts": {
#     "player_name": "Jalen Hurts",
#     "week": 1,
#     "year": 2024,
#     "total_points": 19.42,
#     "projected_points": 21.72,
#     "slot": "QB"
#   },
#   "Vikings D/ST": {
#     "player_name": "Vikings D/ST",
#     "week": 1,
#     "year": 2024,
#     "total_points": 21.0,
#     "projected_points": 7.85,
#     "slot": "D/ST"
#   },
#   "Ja'Marr Chase": {
#     "player_name": "Ja'Marr Chase",
#     "week": 1,
#     "year": 2024,
#     "total_points": 9.2,
#     "projected_points": 13.81,
#     "slot": "WR"
#   },
#   "Saquon Barkley": {
#     "player_name": "Saquon Barkley",
#     "week": 1,
#     "year": 2024,
#     "total_points": 32.2,
#     "projected_points": 15.71,
#     "slot": "FA"
#   },
#   "Deebo Samuel Sr.": {
#     "player_name": "Deebo Samuel Sr.",
#     "week": 1,
#     "year": 2024,
#     "total_points": 16.2,
#     "projected_points": 13.9,
#     "slot": "WR"
#   },
#   "Rachaad White": {
#     "player_name": "Rachaad White",
#     "week": 1,
#     "year": 2024,
#     "total_points": 13.6,
#     "projected_points": 15.46,
#     "slot": "BE"
#   },
#   "Mark Andrews": {
#     "player_name": "Mark Andrews",
#     "week": 1,
#     "year": 2024,
#     "total_points": 2.4,
#     "projected_points": 10.66,
#     "slot": "TE"
#   },
#   "Anthony Richardson": {
#     "player_name": "Anthony Richardson",
#     "week": 1,
#     "year": 2024,
#     "total_points": 32.08,
#     "projected_points": 19.6,
#     "slot": "FA"
#   },
#   "Amari Cooper": {
#     "player_name": "Amari Cooper",
#     "week": 1,
#     "year": 2024,
#     "total_points": 2.6,
#     "projected_points": 11.35,
#     "slot": "FA"
#   },
#   "George Pickens": {
#     "player_name": "George Pickens",
#     "week": 1,
#     "year": 2024,
#     "total_points": 10.5,
#     "projected_points": 10.73,
#     "slot": "BE"
#   },
#   "Terry McLaurin": {
#     "player_name": "Terry McLaurin",
#     "week": 1,
#     "year": 2024,
#     "total_points": 2.7,
#     "projected_points": 10.74,
#     "slot": "BE"
#   },
#   "Nick Chubb": {
#     "player_name": "Nick Chubb",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0.0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Jerome Ford": {
#     "player_name": "Jerome Ford",
#     "week": 1,
#     "year": 2024,
#     "total_points": 15.9,
#     "projected_points": 10.65,
#     "slot": "BE"
#   },
#   "Gus Edwards": {
#     "player_name": "Gus Edwards",
#     "week": 1,
#     "year": 2024,
#     "total_points": 3.3,
#     "projected_points": 9.12,
#     "slot": "FA"
#   },
#   "J.K. Dobbins": {
#     "player_name": "J.K. Dobbins",
#     "week": 1,
#     "year": 2024,
#     "total_points": 21.4,
#     "projected_points": 10.65,
#     "slot": "RB"
#   },
#   "DeAndre Hopkins": {
#     "player_name": "DeAndre Hopkins",
#     "week": 1,
#     "year": 2024,
#     "total_points": 1.3,
#     "projected_points": 9.73,
#     "slot": "BE"
#   },
#   "Evan McPherson": {
#     "player_name": "Evan McPherson",
#     "week": 1,
#     "year": 2024,
#     "total_points": 6.0,
#     "projected_points": 8.35,
#     "slot": "FA"
#   },
#   "Bengals D/ST": {
#     "player_name": "Bengals D/ST",
#     "week": 1,
#     "year": 2024,
#     "total_points": 4.0,
#     "projected_points": 7.86,
#     "slot": "FA"
#   },
#   "Seahawks D/ST": {
#     "player_name": "Seahawks D/ST",
#     "week": 1,
#     "year": 2024,
#     "total_points": 11.0,
#     "projected_points": 7.98,
#     "slot": "BE"
#   },
#   "Chase McLaughlin": {
#     "player_name": "Chase McLaughlin",
#     "week": 1,
#     "year": 2024,
#     "total_points": 15.0,
#     "projected_points": 8.12,
#     "slot": "FA"
#   },
#   "Chris Boswell": {
#     "player_name": "Chris Boswell",
#     "week": 1,
#     "year": 2024,
#     "total_points": 26.0,
#     "projected_points": 7.62,
#     "slot": "FA"
#   },
#   "Jerry Jeudy": {
#     "player_name": "Jerry Jeudy",
#     "week": 1,
#     "year": 2024,
#     "total_points": 10.0,
#     "projected_points": 9.38,
#     "slot": "FA"
#   },
#   "Brock Purdy": {
#     "player_name": "Brock Purdy",
#     "week": 1,
#     "year": 2024,
#     "total_points": 10.34,
#     "projected_points": 17.17,
#     "slot": "FA"
#   },
#   "Chuba Hubbard": {
#     "player_name": "Chuba Hubbard",
#     "week": 1,
#     "year": 2024,
#     "total_points": 1.4,
#     "projected_points": 10.48,
#     "slot": "FA"
#   },
#   "Cade Otton": {
#     "player_name": "Cade Otton",
#     "week": 1,
#     "year": 2024,
#     "total_points": 1.0,
#     "projected_points": 6.18,
#     "slot": "FA"
#   },
#   "Packers D/ST": {
#     "player_name": "Packers D/ST",
#     "week": 1,
#     "year": 2024,
#     "total_points": 4.0,
#     "projected_points": 4.86,
#     "slot": "FA"
#   },
#   "Pat Freiermuth": {
#     "player_name": "Pat Freiermuth",
#     "week": 1,
#     "year": 2024,
#     "total_points": 4.7,
#     "projected_points": 7.05,
#     "slot": "FA"
#   },
#   "Alexander Mattison": {
#     "player_name": "Alexander Mattison",
#     "week": 1,
#     "year": 2024,
#     "total_points": 14.2,
#     "projected_points": 4.83,
#     "slot": "FA"
#   },
#   "Tua Tagovailoa": {
#     "player_name": "Tua Tagovailoa",
#     "week": 1,
#     "year": 2024,
#     "total_points": 21.62,
#     "projected_points": 15.88,
#     "slot": "FA"
#   },
#   "Bills D/ST": {
#     "player_name": "Bills D/ST",
#     "week": 1,
#     "year": 2024,
#     "total_points": 7.0,
#     "projected_points": 5.37,
#     "slot": "FA"
#   },
#   "Aaron Rodgers": {
#     "player_name": "Aaron Rodgers",
#     "week": 1,
#     "year": 2024,
#     "total_points": 8.58,
#     "projected_points": 16.71,
#     "slot": "FA"
#   },
#   "Geno Smith": {
#     "player_name": "Geno Smith",
#     "week": 1,
#     "year": 2024,
#     "total_points": 17.84,
#     "projected_points": 17.7,
#     "slot": "FA"
#   },
#   "Dalton Schultz": {
#     "player_name": "Dalton Schultz",
#     "week": 1,
#     "year": 2024,
#     "total_points": 3.1,
#     "projected_points": 7.36,
#     "slot": "FA"
#   },
#   "Kirk Cousins": {
#     "player_name": "Kirk Cousins",
#     "week": 1,
#     "year": 2024,
#     "total_points": 6.2,
#     "projected_points": 16.01,
#     "slot": "FA"
#   },
#   "Romeo Doubs": {
#     "player_name": "Romeo Doubs",
#     "week": 1,
#     "year": 2024,
#     "total_points": 7.0,
#     "projected_points": 7.43,
#     "slot": "FA"
#   },
#   "Wan'Dale Robinson": {
#     "player_name": "Wan'Dale Robinson",
#     "week": 1,
#     "year": 2024,
#     "total_points": 8.8,
#     "projected_points": 6.36,
#     "slot": "FA"
#   },
#   "Matthew Stafford": {
#     "player_name": "Matthew Stafford",
#     "week": 1,
#     "year": 2024,
#     "total_points": 14.68,
#     "projected_points": 16.85,
#     "slot": "FA"
#   },
#   "Jake Moody": {
#     "player_name": "Jake Moody",
#     "week": 1,
#     "year": 2024,
#     "total_points": 26.0,
#     "projected_points": 7.91,
#     "slot": "FA"
#   },
#   "Kendre Miller": {
#     "player_name": "Kendre Miller",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0.0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Cardinals D/ST": {
#     "player_name": "Cardinals D/ST",
#     "week": 1,
#     "year": 2024,
#     "total_points": 8.0,
#     "projected_points": 2.56,
#     "slot": "FA"
#   },
#   "Cole Kmet": {
#     "player_name": "Cole Kmet",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0.9,
#     "projected_points": 5.64,
#     "slot": "FA"
#   },
#   "Hollywood Brown": {
#     "player_name": "Hollywood Brown",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0.0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Mike Gesicki": {
#     "player_name": "Mike Gesicki",
#     "week": 1,
#     "year": 2024,
#     "total_points": 3.3,
#     "projected_points": 4.63,
#     "slot": "FA"
#   },
#   "Will Reichard": {
#     "player_name": "Will Reichard",
#     "week": 1,
#     "year": 2024,
#     "total_points": 4.0,
#     "projected_points": 7.55,
#     "slot": "FA"
#   },
#   "Braelon Allen": {
#     "player_name": "Braelon Allen",
#     "week": 1,
#     "year": 2024,
#     "total_points": 2.2,
#     "projected_points": 2.76,
#     "slot": "FA"
#   },
#   "Xavier Legette": {
#     "player_name": "Xavier Legette",
#     "week": 1,
#     "year": 2024,
#     "total_points": 5.5,
#     "projected_points": 3.61,
#     "slot": "FA"
#   },
#   "Isaiah Likely": {
#     "player_name": "Isaiah Likely",
#     "week": 1,
#     "year": 2024,
#     "total_points": 22.6,
#     "projected_points": 4.03,
#     "slot": "FA"
#   },
#   "Drake Maye": {
#     "player_name": "Drake Maye",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0.0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Cedric Tillman": {
#     "player_name": "Cedric Tillman",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0.8,
#     "projected_points": 3.32,
#     "slot": "FA"
#   },
#   "Nick Folk": {
#     "player_name": "Nick Folk",
#     "week": 1,
#     "year": 2024,
#     "total_points": 6.0,
#     "projected_points": 7.76,
#     "slot": "FA"
#   },
#   "Brandon McManus": {
#     "player_name": "Brandon McManus",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Rashod Bateman": {
#     "player_name": "Rashod Bateman",
#     "week": 1,
#     "year": 2024,
#     "total_points": 6.3,
#     "projected_points": 6.03,
#     "slot": "FA"
#   },
#   "Titans D/ST": {
#     "player_name": "Titans D/ST",
#     "week": 1,
#     "year": 2024,
#     "total_points": 7.0,
#     "projected_points": 5.82,
#     "slot": "FA"
#   },
#   "Bears D/ST": {
#     "player_name": "Bears D/ST",
#     "week": 1,
#     "year": 2024,
#     "total_points": 26.0,
#     "projected_points": 7.38,
#     "slot": "FA"
#   },
#   "Justice Hill": {
#     "player_name": "Justice Hill",
#     "week": 1,
#     "year": 2024,
#     "total_points": 8.5,
#     "projected_points": 4.76,
#     "slot": "FA"
#   },
#   "Rashid Shaheed": {
#     "player_name": "Rashid Shaheed",
#     "week": 1,
#     "year": 2024,
#     "total_points": 23.8,
#     "projected_points": 9.8,
#     "slot": "FA"
#   },
#   "Antonio Gibson": {
#     "player_name": "Antonio Gibson",
#     "week": 1,
#     "year": 2024,
#     "total_points": 1.8,
#     "projected_points": 7.18,
#     "slot": "FA"
#   },
#   "Ray Davis": {
#     "player_name": "Ray Davis",
#     "week": 1,
#     "year": 2024,
#     "total_points": 3.2,
#     "projected_points": 4.09,
#     "slot": "FA"
#   },
#   "Cairo Santos": {
#     "player_name": "Cairo Santos",
#     "week": 1,
#     "year": 2024,
#     "total_points": 13.0,
#     "projected_points": 8.18,
#     "slot": "FA"
#   },
#   "Austin Seibert": {
#     "player_name": "Austin Seibert",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Patrick Taylor Jr.": {
#     "player_name": "Patrick Taylor Jr.",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0.0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Tyler Conklin": {
#     "player_name": "Tyler Conklin",
#     "week": 1,
#     "year": 2024,
#     "total_points": 1.1,
#     "projected_points": 6.77,
#     "slot": "FA"
#   },
#   "Marquez Valdes-Scantling": {
#     "player_name": "Marquez Valdes-Scantling",
#     "week": 1,
#     "year": 2024,
#     "total_points": 2.4,
#     "projected_points": 0.54,
#     "slot": "FA"
#   },
#   "Elijah Moore": {
#     "player_name": "Elijah Moore",
#     "week": 1,
#     "year": 2024,
#     "total_points": 2.4,
#     "projected_points": 4.01,
#     "slot": "FA"
#   },
#   "Brandin Cooks": {
#     "player_name": "Brandin Cooks",
#     "week": 1,
#     "year": 2024,
#     "total_points": 12.5,
#     "projected_points": 7.44,
#     "slot": "FA"
#   },
#   "Ricky Pearsall": {
#     "player_name": "Ricky Pearsall",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0.0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Juwan Johnson": {
#     "player_name": "Juwan Johnson",
#     "week": 1,
#     "year": 2024,
#     "total_points": 9.6,
#     "projected_points": 6.69,
#     "slot": "FA"
#   },
#   "Jaguars D/ST": {
#     "player_name": "Jaguars D/ST",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0.0,
#     "projected_points": 4.55,
#     "slot": "FA"
#   },
#   "Bryce Young": {
#     "player_name": "Bryce Young",
#     "week": 1,
#     "year": 2024,
#     "total_points": 9.64,
#     "projected_points": 13.87,
#     "slot": "FA"
#   },
#   "Michael Penix Jr.": {
#     "player_name": "Michael Penix Jr.",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0.0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Kimani Vidal": {
#     "player_name": "Kimani Vidal",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0.0,
#     "projected_points": 0.43,
#     "slot": "FA"
#   },
#   "Trevor Lawrence": {
#     "player_name": "Trevor Lawrence",
#     "week": 1,
#     "year": 2024,
#     "total_points": 11.28,
#     "projected_points": 15.99,
#     "slot": "FA"
#   },
#   "Ray-Ray McCloud III": {
#     "player_name": "Ray-Ray McCloud III",
#     "week": 1,
#     "year": 2024,
#     "total_points": 7.2,
#     "projected_points": 4.05,
#     "slot": "FA"
#   },
#   "Gabe Davis": {
#     "player_name": "Gabe Davis",
#     "week": 1,
#     "year": 2024,
#     "total_points": 7.7,
#     "projected_points": 8.25,
#     "slot": "FA"
#   },
#   "Cam Akers": {
#     "player_name": "Cam Akers",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0.0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Noah Gray": {
#     "player_name": "Noah Gray",
#     "week": 1,
#     "year": 2024,
#     "total_points": 5.2,
#     "projected_points": 2.85,
#     "slot": "FA"
#   },
#   "Demarcus Robinson": {
#     "player_name": "Demarcus Robinson",
#     "week": 1,
#     "year": 2024,
#     "total_points": 6.2,
#     "projected_points": 7.31,
#     "slot": "FA"
#   },
#   "Raiders D/ST": {
#     "player_name": "Raiders D/ST",
#     "week": 1,
#     "year": 2024,
#     "total_points": 1.0,
#     "projected_points": 4.37,
#     "slot": "FA"
#   },
#   "Sincere McCormick": {
#     "player_name": "Sincere McCormick",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0,
#     "slot": "FA"
#   },
#   "Jameis Winston": {
#     "player_name": "Jameis Winston",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0.0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Derek Carr": {
#     "player_name": "Derek Carr",
#     "week": 1,
#     "year": 2024,
#     "total_points": 24.3,
#     "projected_points": 15.42,
#     "slot": "FA"
#   },
#   "Alec Pierce": {
#     "player_name": "Alec Pierce",
#     "week": 1,
#     "year": 2024,
#     "total_points": 23.0,
#     "projected_points": 5.68,
#     "slot": "FA"
#   },
#   "Allen Lazard": {
#     "player_name": "Allen Lazard",
#     "week": 1,
#     "year": 2024,
#     "total_points": 23.9,
#     "projected_points": 4.73,
#     "slot": "FA"
#   },
#   "Joshua Palmer": {
#     "player_name": "Joshua Palmer",
#     "week": 1,
#     "year": 2024,
#     "total_points": 2.5,
#     "projected_points": 9.97,
#     "slot": "FA"
#   },
#   "Curtis Samuel": {
#     "player_name": "Curtis Samuel",
#     "week": 1,
#     "year": 2024,
#     "total_points": 2.5,
#     "projected_points": 9.01,
#     "slot": "FA"
#   },
#   "Clyde Edwards-Helaire": {
#     "player_name": "Clyde Edwards-Helaire",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0.0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Dontayvion Wicks": {
#     "player_name": "Dontayvion Wicks",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0.0,
#     "projected_points": 6.41,
#     "slot": "FA"
#   },
#   "Justin Fields": {
#     "player_name": "Justin Fields",
#     "week": 1,
#     "year": 2024,
#     "total_points": 11.94,
#     "projected_points": 18.16,
#     "slot": "FA"
#   },
#   "Dawson Knox": {
#     "player_name": "Dawson Knox",
#     "week": 1,
#     "year": 2024,
#     "total_points": 2.8,
#     "projected_points": 3.7,
#     "slot": "FA"
#   },
#   "Michael Wilson": {
#     "player_name": "Michael Wilson",
#     "week": 1,
#     "year": 2024,
#     "total_points": 7.0,
#     "projected_points": 7.15,
#     "slot": "FA"
#   },
#   "Jalen Coker": {
#     "player_name": "Jalen Coker",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0,
#     "slot": "FA"
#   },
#   "Jalen Tolbert": {
#     "player_name": "Jalen Tolbert",
#     "week": 1,
#     "year": 2024,
#     "total_points": 1.7,
#     "projected_points": 5.43,
#     "slot": "FA"
#   },
#   "Joe Flacco": {
#     "player_name": "Joe Flacco",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0.0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Tre Tucker": {
#     "player_name": "Tre Tucker",
#     "week": 1,
#     "year": 2024,
#     "total_points": 6.0,
#     "projected_points": 6.81,
#     "slot": "FA"
#   },
#   "Roschon Johnson": {
#     "player_name": "Roschon Johnson",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0.0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Audric Estime": {
#     "player_name": "Audric Estime",
#     "week": 1,
#     "year": 2024,
#     "total_points": 1.4,
#     "projected_points": 1.89,
#     "slot": "FA"
#   },
#   "Kenneth Gainwell": {
#     "player_name": "Kenneth Gainwell",
#     "week": 1,
#     "year": 2024,
#     "total_points": 1.7,
#     "projected_points": 2.29,
#     "slot": "FA"
#   },
#   "Blake Grupe": {
#     "player_name": "Blake Grupe",
#     "week": 1,
#     "year": 2024,
#     "total_points": 22.0,
#     "projected_points": 7.45,
#     "slot": "FA"
#   },
#   "Joshua Karty": {
#     "player_name": "Joshua Karty",
#     "week": 1,
#     "year": 2024,
#     "total_points": 9.0,
#     "projected_points": 7.69,
#     "slot": "FA"
#   },
#   "Khalil Herbert": {
#     "player_name": "Khalil Herbert",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0.4,
#     "projected_points": 8.32,
#     "slot": "FA"
#   },
#   "Colby Parkinson": {
#     "player_name": "Colby Parkinson",
#     "week": 1,
#     "year": 2024,
#     "total_points": 6.7,
#     "projected_points": 5.81,
#     "slot": "FA"
#   },
#   "Sterling Shepard": {
#     "player_name": "Sterling Shepard",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Kayshon Boutte": {
#     "player_name": "Kayshon Boutte",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0.0,
#     "projected_points": 2.1,
#     "slot": "FA"
#   },
#   "Deshaun Watson": {
#     "player_name": "Deshaun Watson",
#     "week": 1,
#     "year": 2024,
#     "total_points": 10.66,
#     "projected_points": 17.02,
#     "slot": "FA"
#   },
#   "Matthew Wright": {
#     "player_name": "Matthew Wright",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Chad Ryland": {
#     "player_name": "Chad Ryland",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Rams D/ST": {
#     "player_name": "Rams D/ST",
#     "week": 1,
#     "year": 2024,
#     "total_points": 3.0,
#     "projected_points": 2.87,
#     "slot": "FA"
#   },
#   "Adonai Mitchell": {
#     "player_name": "Adonai Mitchell",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0.7,
#     "projected_points": 5.63,
#     "slot": "FA"
#   },
#   "MarShawn Lloyd": {
#     "player_name": "MarShawn Lloyd",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0.0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Dustin Hopkins": {
#     "player_name": "Dustin Hopkins",
#     "week": 1,
#     "year": 2024,
#     "total_points": 7.0,
#     "projected_points": 7.78,
#     "slot": "FA"
#   },
#   "Darius Slayton": {
#     "player_name": "Darius Slayton",
#     "week": 1,
#     "year": 2024,
#     "total_points": 4.1,
#     "projected_points": 5.58,
#     "slot": "FA"
#   },
#   "Cooper Rush": {
#     "player_name": "Cooper Rush",
#     "week": 1,
#     "year": 2024,
#     "total_points": -0.1,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Raheem Blackshear": {
#     "player_name": "Raheem Blackshear",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0.0,
#     "projected_points": 2.46,
#     "slot": "FA"
#   },
#   "Ja'Lynn Polk": {
#     "player_name": "Ja'Lynn Polk",
#     "week": 1,
#     "year": 2024,
#     "total_points": 1.1,
#     "projected_points": 7.67,
#     "slot": "FA"
#   },
#   "Daniel Jones": {
#     "player_name": "Daniel Jones",
#     "week": 1,
#     "year": 2024,
#     "total_points": 4.94,
#     "projected_points": 17.18,
#     "slot": "FA"
#   },
#   "Zane Gonzalez": {
#     "player_name": "Zane Gonzalez",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0,
#     "slot": "FA"
#   },
#   "Spencer Shrader": {
#     "player_name": "Spencer Shrader",
#     "week": 1,
#     "year": 2024,
#     "total_points": 3.0,
#     "projected_points": 7.72,
#     "slot": "FA"
#   },
#   "Trey Sermon": {
#     "player_name": "Trey Sermon",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0.0,
#     "projected_points": 2.08,
#     "slot": "FA"
#   },
#   "Jaylen Wright": {
#     "player_name": "Jaylen Wright",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0.0,
#     "projected_points": 0.08,
#     "slot": "FA"
#   },
#   "Miles Sanders": {
#     "player_name": "Miles Sanders",
#     "week": 1,
#     "year": 2024,
#     "total_points": 2.2,
#     "projected_points": 6.45,
#     "slot": "FA"
#   },
#   "Luke Schoonmaker": {
#     "player_name": "Luke Schoonmaker",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0.0,
#     "projected_points": 1.92,
#     "slot": "FA"
#   },
#   "Mason Rudolph": {
#     "player_name": "Mason Rudolph",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0.0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Carson Steele": {
#     "player_name": "Carson Steele",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0.3,
#     "projected_points": 0.93,
#     "slot": "FA"
#   },
#   "JuJu Smith-Schuster": {
#     "player_name": "JuJu Smith-Schuster",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0.0,
#     "projected_points": 1.82,
#     "slot": "FA"
#   },
#   "Mac Jones": {
#     "player_name": "Mac Jones",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0.0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Samaje Perine": {
#     "player_name": "Samaje Perine",
#     "week": 1,
#     "year": 2024,
#     "total_points": 1.5,
#     "projected_points": 3.73,
#     "slot": "FA"
#   },
#   "Olamide Zaccheaus": {
#     "player_name": "Olamide Zaccheaus",
#     "week": 1,
#     "year": 2024,
#     "total_points": 2.0,
#     "projected_points": 3.79,
#     "slot": "FA"
#   },
#   "Giants D/ST": {
#     "player_name": "Giants D/ST",
#     "week": 1,
#     "year": 2024,
#     "total_points": 5.0,
#     "projected_points": 6.67,
#     "slot": "FA"
#   },
#   "Tommy DeVito": {
#     "player_name": "Tommy DeVito",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0.0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Tim Patrick": {
#     "player_name": "Tim Patrick",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Cade York": {
#     "player_name": "Cade York",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0.0,
#     "projected_points": 7.23,
#     "slot": "FA"
#   },
#   "Daniel Carlson": {
#     "player_name": "Daniel Carlson",
#     "week": 1,
#     "year": 2024,
#     "total_points": 3.0,
#     "projected_points": 7.74,
#     "slot": "FA"
#   },
#   "Jeremy McNichols": {
#     "player_name": "Jeremy McNichols",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0.0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Calvin Austin III": {
#     "player_name": "Calvin Austin III",
#     "week": 1,
#     "year": 2024,
#     "total_points": 5.9,
#     "projected_points": 5.19,
#     "slot": "FA"
#   },
#   "Isaiah Davis": {
#     "player_name": "Isaiah Davis",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0.0,
#     "projected_points": 2.46,
#     "slot": "FA"
#   },
#   "Mike Boone": {
#     "player_name": "Mike Boone",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0.7,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Parker Washington": {
#     "player_name": "Parker Washington",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0.8,
#     "projected_points": 0.13,
#     "slot": "FA"
#   },
#   "Andrei Iosivas": {
#     "player_name": "Andrei Iosivas",
#     "week": 1,
#     "year": 2024,
#     "total_points": 4.1,
#     "projected_points": 8.34,
#     "slot": "FA"
#   },
#   "Jamaal Williams": {
#     "player_name": "Jamaal Williams",
#     "week": 1,
#     "year": 2024,
#     "total_points": 11.6,
#     "projected_points": 5.04,
#     "slot": "FA"
#   },
#   "Aidan O'Connell": {
#     "player_name": "Aidan O'Connell",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0.0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Tyler Huntley": {
#     "player_name": "Tyler Huntley",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Tutu Atwell": {
#     "player_name": "Tutu Atwell",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0.0,
#     "projected_points": 1.78,
#     "slot": "FA"
#   },
#   "Craig Reynolds": {
#     "player_name": "Craig Reynolds",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0.0,
#     "projected_points": 0.03,
#     "slot": "FA"
#   },
#   "Patriots D/ST": {
#     "player_name": "Patriots D/ST",
#     "week": 1,
#     "year": 2024,
#     "total_points": 12.0,
#     "projected_points": 4.07,
#     "slot": "FA"
#   },
#   "John Parker Romo": {
#     "player_name": "John Parker Romo",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0,
#     "slot": "FA"
#   },
#   "Ty Johnson": {
#     "player_name": "Ty Johnson",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0.7,
#     "projected_points": 2.48,
#     "slot": "FA"
#   },
#   "Devaughn Vele": {
#     "player_name": "Devaughn Vele",
#     "week": 1,
#     "year": 2024,
#     "total_points": 7.9,
#     "projected_points": 1.16,
#     "slot": "FA"
#   },
#   "Tyler Boyd": {
#     "player_name": "Tyler Boyd",
#     "week": 1,
#     "year": 2024,
#     "total_points": 3.3,
#     "projected_points": 5.57,
#     "slot": "FA"
#   },
#   "Eddy Pineiro": {
#     "player_name": "Eddy Pineiro",
#     "week": 1,
#     "year": 2024,
#     "total_points": 5.0,
#     "projected_points": 7.55,
#     "slot": "FA"
#   },
#   "Theo Johnson": {
#     "player_name": "Theo Johnson",
#     "week": 1,
#     "year": 2024,
#     "total_points": 2.3,
#     "projected_points": 3.78,
#     "slot": "FA"
#   },
#   "Emanuel Wilson": {
#     "player_name": "Emanuel Wilson",
#     "week": 1,
#     "year": 2024,
#     "total_points": 5.8,
#     "projected_points": 4.2,
#     "slot": "FA"
#   },
#   "Dameon Pierce": {
#     "player_name": "Dameon Pierce",
#     "week": 1,
#     "year": 2024,
#     "total_points": 1.6,
#     "projected_points": 2.78,
#     "slot": "FA"
#   },
#   "D'Onta Foreman": {
#     "player_name": "D'Onta Foreman",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0.0,
#     "projected_points": 5.08,
#     "slot": "FA"
#   },
#   "Kendrick Bourne": {
#     "player_name": "Kendrick Bourne",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0.0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Michael Mayer": {
#     "player_name": "Michael Mayer",
#     "week": 1,
#     "year": 2024,
#     "total_points": 1.3,
#     "projected_points": 2.6,
#     "slot": "FA"
#   },
#   "Joshua Dobbs": {
#     "player_name": "Joshua Dobbs",
#     "week": 1,
# ...
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Sammis Reyes": {
#     "player_name": "Sammis Reyes",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Trenton Cannon": {
#     "player_name": "Trenton Cannon",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Devon Allen": {
#     "player_name": "Devon Allen",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Cornell Powell": {
#     "player_name": "Cornell Powell",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Jared Pinkney": {
#     "player_name": "Jared Pinkney",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Noah Togiai": {
#     "player_name": "Noah Togiai",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Tommy Hudson": {
#     "player_name": "Tommy Hudson",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Baylor Cupp": {
#     "player_name": "Baylor Cupp",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0,
#     "slot": "FA"
#   },
#   "Lynn Bowden Jr.": {
#     "player_name": "Lynn Bowden Jr.",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Cole Turner": {
#     "player_name": "Cole Turner",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "David Sills V": {
#     "player_name": "David Sills V",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Kendall Blanton": {
#     "player_name": "Kendall Blanton",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Tony Poljan": {
#     "player_name": "Tony Poljan",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Miller Forristall": {
#     "player_name": "Miller Forristall",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Mike Thomas": {
#     "player_name": "Mike Thomas",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Keke Coutee": {
#     "player_name": "Keke Coutee",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Kaylon Geiger": {
#     "player_name": "Kaylon Geiger",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Trevon Wesco": {
#     "player_name": "Trevon Wesco",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Brandon Dillon": {
#     "player_name": "Brandon Dillon",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Sage Surratt": {
#     "player_name": "Sage Surratt",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Kevin Rader": {
#     "player_name": "Kevin Rader",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Sean McKeon": {
#     "player_name": "Sean McKeon",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "David Wells": {
#     "player_name": "David Wells",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Kwamie Lassiter II": {
#     "player_name": "Kwamie Lassiter II",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Freddie Swain": {
#     "player_name": "Freddie Swain",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Mitchell Tinsley": {
#     "player_name": "Mitchell Tinsley",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Brandon Smith": {
#     "player_name": "Brandon Smith",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Stephen Sullivan": {
#     "player_name": "Stephen Sullivan",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Daylen Baldwin": {
#     "player_name": "Daylen Baldwin",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Brycen Tremayne": {
#     "player_name": "Brycen Tremayne",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0,
#     "slot": "FA"
#   },
#   "Jack Westover": {
#     "player_name": "Jack Westover",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0,
#     "slot": "FA"
#   },
#   "Tyler Mabry": {
#     "player_name": "Tyler Mabry",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Nikola Kalinic": {
#     "player_name": "Nikola Kalinic",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Jordan Wilkins": {
#     "player_name": "Jordan Wilkins",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Austin Walter": {
#     "player_name": "Austin Walter",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Gerrid Doaks": {
#     "player_name": "Gerrid Doaks",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Racey McMath": {
#     "player_name": "Racey McMath",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Cody Thompson": {
#     "player_name": "Cody Thompson",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Kearis Jackson": {
#     "player_name": "Kearis Jackson",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Dontrell Hilliard": {
#     "player_name": "Dontrell Hilliard",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Josh Ali": {
#     "player_name": "Josh Ali",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Austin Trammell": {
#     "player_name": "Austin Trammell",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Mekhi Sargent": {
#     "player_name": "Mekhi Sargent",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Jeff Smith": {
#     "player_name": "Jeff Smith",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Easop Winston Jr.": {
#     "player_name": "Easop Winston Jr.",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Tory Carter": {
#     "player_name": "Tory Carter",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Javon Wims": {
#     "player_name": "Javon Wims",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Jalen Moreno-Cropper": {
#     "player_name": "Jalen Moreno-Cropper",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0,
#     "slot": "FA"
#   },
#   "Dax Milne": {
#     "player_name": "Dax Milne",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Trey Ragas": {
#     "player_name": "Trey Ragas",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Marcus Kemp": {
#     "player_name": "Marcus Kemp",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Tre Nixon": {
#     "player_name": "Tre Nixon",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Austin Watkins Jr.": {
#     "player_name": "Austin Watkins Jr.",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Dazz Newsome": {
#     "player_name": "Dazz Newsome",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Trestan Ebner": {
#     "player_name": "Trestan Ebner",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Frank Darby": {
#     "player_name": "Frank Darby",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Seth Williams": {
#     "player_name": "Seth Williams",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Andre Roberts": {
#     "player_name": "Andre Roberts",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Raleigh Webb": {
#     "player_name": "Raleigh Webb",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Denzel Mims": {
#     "player_name": "Denzel Mims",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Lance McCutcheon": {
#     "player_name": "Lance McCutcheon",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Cam Sims": {
#     "player_name": "Cam Sims",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Jaylen Johnson": {
#     "player_name": "Jaylen Johnson",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0,
#     "slot": "FA"
#   },
#   "Tay Martin": {
#     "player_name": "Tay Martin",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Penny Hart": {
#     "player_name": "Penny Hart",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Malik Turner": {
#     "player_name": "Malik Turner",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Stanley Morgan Jr.": {
#     "player_name": "Stanley Morgan Jr.",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Tanner Gentry": {
#     "player_name": "Tanner Gentry",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Tyrie Cleveland": {
#     "player_name": "Tyrie Cleveland",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Dennis Houston": {
#     "player_name": "Dennis Houston",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "T.J. Vasher": {
#     "player_name": "T.J. Vasher",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Mike Strachan": {
#     "player_name": "Mike Strachan",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Alex Bachman": {
#     "player_name": "Alex Bachman",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Trinity Benson": {
#     "player_name": "Trinity Benson",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Landen Akers": {
#     "player_name": "Landen Akers",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Keelan Doss": {
#     "player_name": "Keelan Doss",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Andre Baccellia": {
#     "player_name": "Andre Baccellia",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Jason Moore": {
#     "player_name": "Jason Moore",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Cade Johnson": {
#     "player_name": "Cade Johnson",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Myron Mitchell": {
#     "player_name": "Myron Mitchell",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Austin Mack": {
#     "player_name": "Austin Mack",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Jalen Camp": {
#     "player_name": "Jalen Camp",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Davion Davis": {
#     "player_name": "Davion Davis",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "C.J. Board": {
#     "player_name": "C.J. Board",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Cody Hollister": {
#     "player_name": "Cody Hollister",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Marquez Stevenson": {
#     "player_name": "Marquez Stevenson",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Kyric McGowan": {
#     "player_name": "Kyric McGowan",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Michael Bandy": {
#     "player_name": "Michael Bandy",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Bryan Edwards": {
#     "player_name": "Bryan Edwards",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Dezmon Patmon": {
#     "player_name": "Dezmon Patmon",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Kendall Hinton": {
#     "player_name": "Kendall Hinton",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Kawaan Baker": {
#     "player_name": "Kawaan Baker",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0.0,
#     "slot": "FA"
#   },
#   "Anthony Miller": {
#     "player_name": "Anthony Miller",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0,
#     "slot": "FA"
#   },
#   "Joshua Cephus": {
#     "player_name": "Joshua Cephus",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0,
#     "slot": "FA"
#   },
#   "Jacob Kibodi": {
#     "player_name": "Jacob Kibodi",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0,
#     "slot": "FA"
#   },
#   "Carlos Washington Jr.": {
#     "player_name": "Carlos Washington Jr.",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0,
#     "slot": "FA"
#   },
#   "Kaden Davis": {
#     "player_name": "Kaden Davis",
#     "week": 1,
#     "year": 2024,
#     "total_points": 0,
#     "projected_points": 0,
#     "slot": "FA"
#   }
# }
